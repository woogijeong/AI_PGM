# %%
for j in range(1, 100, 10):
    
    for i in range(10):
        print(f"{j} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+1} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+2} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+3} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+4} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+5} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+6} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+7} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+8} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+9} X {i+1} = {j*(i+1)}", end="\t")
        print(f"{j+10} X {i+1} = {j*(i+1)}", end="\n")
    print("\n")
# Out:
# 1 X 1 = 1	2 X 1 = 1	3 X 1 = 1	4 X 1 = 1	5 X 1 = 1	6 X 1 = 1	7 X 1 = 1	8 X 1 = 1	9 X 1 = 1	10 X 1 = 1	11 X 1 = 1
# 1 X 2 = 2	2 X 2 = 2	3 X 2 = 2	4 X 2 = 2	5 X 2 = 2	6 X 2 = 2	7 X 2 = 2	8 X 2 = 2	9 X 2 = 2	10 X 2 = 2	11 X 2 = 2
# 1 X 3 = 3	2 X 3 = 3	3 X 3 = 3	4 X 3 = 3	5 X 3 = 3	6 X 3 = 3	7 X 3 = 3	8 X 3 = 3	9 X 3 = 3	10 X 3 = 3	11 X 3 = 3
# 1 X 4 = 4	2 X 4 = 4	3 X 4 = 4	4 X 4 = 4	5 X 4 = 4	6 X 4 = 4	7 X 4 = 4	8 X 4 = 4	9 X 4 = 4	10 X 4 = 4	11 X 4 = 4
# 1 X 5 = 5	2 X 5 = 5	3 X 5 = 5	4 X 5 = 5	5 X 5 = 5	6 X 5 = 5	7 X 5 = 5	8 X 5 = 5	9 X 5 = 5	10 X 5 = 5	11 X 5 = 5
# 1 X 6 = 6	2 X 6 = 6	3 X 6 = 6	4 X 6 = 6	5 X 6 = 6	6 X 6 = 6	7 X 6 = 6	8 X 6 = 6	9 X 6 = 6	10 X 6 = 6	11 X 6 = 6
# 1 X 7 = 7	2 X 7 = 7	3 X 7 = 7	4 X 7 = 7	5 X 7 = 7	6 X 7 = 7	7 X 7 = 7	8 X 7 = 7	9 X 7 = 7	10 X 7 = 7	11 X 7 = 7
# 1 X 8 = 8	2 X 8 = 8	3 X 8 = 8	4 X 8 = 8	5 X 8 = 8	6 X 8 = 8	7 X 8 = 8	8 X 8 = 8	9 X 8 = 8	10 X 8 = 8	11 X 8 = 8
# ...

# %%
print("3 X 2 = 6")
# Out:
# 3 X 2 = 6
